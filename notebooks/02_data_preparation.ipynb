# %% [markdown]
# # HELPix-R Notebook 02: Data Preparation, Deduplication, and Group-Aware Splitting
#
# Demonstrates SHA-256 deduplication and patient/lesion-grouped splitting preventing train-test leakage.

# %%
import pandas as pd

dedup = pd.read_csv('../results/tables/deduplication_statistics.csv')
splits = pd.read_csv('../results/tables/final_split_statistics.csv')
print('Deduplication Statistics:')
print(dedup)
print('\nSplit Statistics:')
print(splits)
