# %% [markdown]
# # HELPix-R Notebook 06: External Testing on PAD-UFES-20
#
# Evaluates domain shift under smartphone-domain clinical photography without retraining.

# %%
import pandas as pd
ds = pd.read_csv('../results/tables/domain_shift_analysis.csv')
print('Domain Shift Analysis:')
print(ds)
