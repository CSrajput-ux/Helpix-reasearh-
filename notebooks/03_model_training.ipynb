# %% [markdown]
# # HELPix-R Notebook 03: Model Architecture and Training Pipeline
#
# Demonstrates HELPix-R multi-scale feature fusion architecture and training configuration.

# %%
import torch
import sys
sys.path.insert(0, '..')
from src.models.helpix_r import HELPixR

model = HELPixR(num_classes=2)
x = torch.randn(2, 3, 224, 224)
out = model(x)
print('Model output shape:', out.shape)
