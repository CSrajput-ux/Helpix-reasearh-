# %% [markdown]
# # HELPix-R Notebook 05: Probability Calibration via Temperature Scaling
#
# Analyzes pre- vs post-calibration Expected Calibration Error (ECE) and Brier scores.

# %%
import pandas as pd
cal = pd.read_csv('../results/tables/Table_calibration_comparison.csv')
print('Calibration Pre vs Post:')
print(cal)
