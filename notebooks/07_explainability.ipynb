# %% [markdown]
# # HELPix-R Notebook 07: Explainability and Attribution Sensitivity
#
# Inspects Grad-CAM heatmaps and quantitative perturbation deletion tests.

# %%
import pandas as pd
gc = pd.read_csv('../results/tables/gradcam_deletion_results.csv')
print('Grad-CAM Deletion Results:')
print(gc)
