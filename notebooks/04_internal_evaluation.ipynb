# %% [markdown]
# # HELPix-R Notebook 04: Internal Test Evaluation and Baseline Comparisons
#
# Evaluates diagnostic metrics on the 55,130-image internal test set.

# %%
import pandas as pd
final_m = pd.read_csv('../results/metrics/final_metrics.csv')
baselines = pd.read_csv('../results/tables/baseline_comparison.csv')
print('Final Internal & External Metrics:')
print(final_m)
print('\nBaseline Model Comparison:')
print(baselines)
