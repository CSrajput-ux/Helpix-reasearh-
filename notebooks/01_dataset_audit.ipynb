# %% [markdown]
# # HELPix-R Notebook 01: Dataset Audit and Characteristics
#
# This notebook reviews the raw cohort statistics for ISIC 2024 SLICE-3D, HAM10000, PAD-UFES-20, and the local BCN20000 audit.

# %%
import pandas as pd
from pathlib import Path

table1_path = Path('../results/tables/Table_1_dataset_characteristics.csv')
df_table1 = pd.read_csv(table1_path)
df_table1
